// %%
import $ivy.`org.apache.spark::spark-sql:3.2.0` // Or use any other 2.x version here
import $ivy.`sh.almond::almond-spark:0.10.1`

import org.apache.spark._
import org.apache.spark.sql.{functions => func, _}
import org.apache.spark.sql.functions._
import org.apache.spark.sql.types._

import org.slf4j.LoggerFactory
import org.apache.log4j.{Level, Logger}

val spark = SparkSession
      .builder()
      .config("spark.sql.shuffle.partitions", 4)
      .master("local[4]")
      .getOrCreate()

import spark.implicits._

Logger.getRootLogger().setLevel(Level.ERROR)
// Out:
// Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
// 22/05/04 21:09:17 INFO SparkContext: Running Spark version 3.2.0
// 22/05/04 21:09:17 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
// 22/05/04 21:09:17 INFO ResourceUtils: ==============================================================
// 22/05/04 21:09:17 INFO ResourceUtils: No custom resources configured for spark.driver.
// 22/05/04 21:09:17 INFO ResourceUtils: ==============================================================
// 22/05/04 21:09:17 INFO SparkContext: Submitted application: 88546275-fdbc-4046-85f1-370d0d438a2e
// 22/05/04 21:09:17 INFO ResourceProfile: Default ResourceProfile created, executor resources: Map(cores -> name: cores, amount: 1, script: , vendor: , memory -> name: memory, amount: 1024, script: , vendor: , offHeap -> name: offHeap, amount: 0, script: , vendor: ), task resources: Map(cpus -> name: cpus, amount: 1.0)
// 22/05/04 21:09:17 INFO ResourceProfile: Limiting resource is cpu
// 22/05/04 21:09:17 INFO ResourceProfileManager: Added ResourceProfile id: 0
// 22/05/04 21:09:17 INFO SecurityManager: Changing view acls to: oscar
// 22/05/04 21:09:17 INFO SecurityManager: Changing modify acls to: oscar
// 22/05/04 21:09:17 INFO SecurityManager: Changing view acls groups to:
// 22/05/04 21:09:17 INFO SecurityManager: Changing modify acls groups to:
// 22/05/04 21:09:17 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(oscar); groups with view permissions: Set(); users  with modify permissions: Set(oscar); groups with modify permissions: Set()
// 22/05/04 21:09:18 INFO Utils: Successfully started service 'sparkDriver' on port 44941.
// 22/05/04 21:09:18 INFO SparkEnv: Registering MapOutputTracker
// 22/05/04 21:09:18 INFO SparkEnv: Registering BlockManagerMaster
// 22/05/04 21:09:18 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
// 22/05/04 21:09:18 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
// 22/05/04 21:09:18 INFO SparkEnv: Registering BlockManagerMasterHeartbeat
// 22/05/04 21:09:18 INFO DiskBlockManager: Created local directory at /tmp/blockmgr-7852c556-d199-4357-8969-59fb90ab487b
// 22/05/04 21:09:18 INFO MemoryStore: MemoryStore started with capacity 4.0 GiB
// 22/05/04 21:09:18 INFO SparkEnv: Registering OutputCommitCoordinator
// 22/05/04 21:09:18 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
// 22/05/04 21:09:18 INFO Utils: Successfully started service 'SparkUI' on port 4041.
// 22/05/04 21:09:18 INFO SparkUI: Bound SparkUI to 0.0.0.0, and started at http://netrunner:4041
// 22/05/04 21:09:18 INFO Executor: Starting executor ID driver on host netrunner
// 22/05/04 21:09:18 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 34893.
// 22/05/04 21:09:18 INFO NettyBlockTransferService: Server created on netrunner:34893
// 22/05/04 21:09:18 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
// 22/05/04 21:09:18 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, netrunner, 34893, None)
// 22/05/04 21:09:18 INFO BlockManagerMasterEndpoint: Registering block manager netrunner:34893 with 4.0 GiB RAM, BlockManagerId(driver, netrunner, 34893, None)
// 22/05/04 21:09:18 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, netrunner, 34893, None)
// 22/05/04 21:09:18 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, netrunner, 34893, None)
// import $ivy.$                                   // Or use any other 2.x version here
//
// import $ivy.$
//
//
// import org.apache.spark._
//
// import org.apache.spark.sql.{functions => func, _}
//
// import org.apache.spark.sql.functions._
//
// import org.apache.spark.sql.types._
//
//
// import org.slf4j.LoggerFactory
//
// import org.apache.log4j.{Level, Logger}
//
//
// spark: SparkSession = org.apache.spark.sql.SparkSession@71d2d250
// import spark.implicits._

// %%
import org.apache.spark.sql.expressions.Window
// Out:
// import org.apache.spark.sql.expressions.Window

// %%
val races = spark.read.parquet("../../data/parquet/races.parquet")
    .where(col("year") === 2012)
// Out:
// races: Dataset[Row] = [raceId: string, year: string ... 6 more fields]

// %%
val lapTimeToMs = (time: String) => {
    val regex = """([0-9]|[0-9][0-9]):([0-9][0-9])\.([0-9][0-9][0-9])""".r
    time match {
        case regex(min,sec,ms) => min.toInt * 60 * 1000 + sec.toInt * 1000 + ms.toInt
        case "\\N" => 180000
    }
    
}: Long
// Out:
// lapTimeToMs: String => Long = ammonite.$sess.cmd3$Helper$$Lambda$4730/1947451798@766e9d12

// %%
val lapTimeToMsUDF = udf(lapTimeToMs)
spark.udf.register("lapTimeToMs", lapTimeToMsUDF)
// Out:
// lapTimeToMsUDF: expressions.UserDefinedFunction = SparkUserDefinedFunction(
//   ammonite.$sess.cmd3$Helper$$Lambda$4730/1947451798@766e9d12,
//   LongType,
//   List(
//     Some(
//       ExpressionEncoder(
//         StaticInvoke(
//           class org.apache.spark.unsafe.types.UTF8String,
//           StringType,
//           "fromString",
//           List(BoundReference(0, ObjectType(class java.lang.String), true)),
//           List(),
//           true,
//           false
//         ),
//         Invoke(
//           UpCast(
//             GetColumnByOrdinal(0, StringType),
//             StringType,
//             List("- root class: \"java.lang.String\"")
//           ),
//           "toString",
//           ObjectType(class java.lang.String),
//           List(),
//           List(),
//           true,
//           false
//         ),
//         java.lang.String
//       )
//     )
//   ),
//   Some(
//     ExpressionEncoder(
//       BoundReference(0, LongType, false),
//       AssertNotNull(
//         UpCast(
//           GetColumnByOrdinal(0, LongType),
//           LongType,
// ...
// res4_1: expressions.UserDefinedFunction = SparkUserDefinedFunction(
//   ammonite.$sess.cmd3$Helper$$Lambda$4730/1947451798@766e9d12,
//   LongType,
//   List(
//     Some(
//       ExpressionEncoder(
//         StaticInvoke(
//           class org.apache.spark.unsafe.types.UTF8String,
//           StringType,
//           "fromString",
//           List(BoundReference(0, ObjectType(class java.lang.String), true)),
//           List(),
//           true,
//           false
//         ),
//         Invoke(
//           UpCast(
//             GetColumnByOrdinal(0, StringType),
//             StringType,
//             List("- root class: \"java.lang.String\"")
//           ),
//           "toString",
//           ObjectType(class java.lang.String),
//           List(),
//           List(),
//           true,
//           false
//         ),
//         java.lang.String
//       )
//     )
//   ),
//   Some(
//     ExpressionEncoder(
//       BoundReference(0, LongType, false),
//       AssertNotNull(
//         UpCast(
//           GetColumnByOrdinal(0, LongType),
//           LongType,
// ...

// %%
val msToLapTime = (time: Long) => {
    val mins = time / 60000
    val secs = (time - mins*60000)/1000
    val ms = time - mins*60000 - secs*1000
    
    val formattedSecs = if((secs / 10).toInt == 0) "0" + secs else secs
    // if ms = 00x -> "0"+"0"+x . if ms = 0xx -> "0"+ms
    val formattedMs = if((ms / 100).toInt == 0) "0" + (if((ms / 10).toInt == 0) "0" + ms else ms) else ms
    mins + ":" + formattedSecs + "." + formattedMs    
}: String
// Out:
// msToLapTime: Long => String = ammonite.$sess.cmd5$Helper$$Lambda$4882/1684045555@44d5bb62

// %%
msToLapTime(lapTimeToMs("1:30.234"))
// Out:
// res6: String = "1:30.234"

// %%
val msToLapTimeUDF = udf(msToLapTime)
spark.udf.register("msToLapTime", msToLapTimeUDF)
// Out:
// msToLapTimeUDF: expressions.UserDefinedFunction = SparkUserDefinedFunction(
//   ammonite.$sess.cmd5$Helper$$Lambda$4882/1684045555@44d5bb62,
//   StringType,
//   List(
//     Some(
//       ExpressionEncoder(
//         BoundReference(0, LongType, false),
//         AssertNotNull(
//           UpCast(
//             GetColumnByOrdinal(0, LongType),
//             LongType,
//             List("- root class: \"scala.Long\"")
//           ),
//           List("- root class: \"scala.Long\"")
//         ),
//         Long
//       )
//     )
//   ),
//   Some(
//     ExpressionEncoder(
//       StaticInvoke(
//         class org.apache.spark.unsafe.types.UTF8String,
//         StringType,
//         "fromString",
//         List(BoundReference(0, ObjectType(class java.lang.String), true)),
//         List(),
//         true,
//         false
//       ),
//       Invoke(
//         UpCast(
//           GetColumnByOrdinal(0, StringType),
//           StringType,
//           List("- root class: \"java.lang.String\"")
//         ),
//         "toString",
//         ObjectType(class java.lang.String),
//         List(),
// ...
// res7_1: expressions.UserDefinedFunction = SparkUserDefinedFunction(
//   ammonite.$sess.cmd5$Helper$$Lambda$4882/1684045555@44d5bb62,
//   StringType,
//   List(
//     Some(
//       ExpressionEncoder(
//         BoundReference(0, LongType, false),
//         AssertNotNull(
//           UpCast(
//             GetColumnByOrdinal(0, LongType),
//             LongType,
//             List("- root class: \"scala.Long\"")
//           ),
//           List("- root class: \"scala.Long\"")
//         ),
//         Long
//       )
//     )
//   ),
//   Some(
//     ExpressionEncoder(
//       StaticInvoke(
//         class org.apache.spark.unsafe.types.UTF8String,
//         StringType,
//         "fromString",
//         List(BoundReference(0, ObjectType(class java.lang.String), true)),
//         List(),
//         true,
//         false
//       ),
//       Invoke(
//         UpCast(
//           GetColumnByOrdinal(0, StringType),
//           StringType,
//           List("- root class: \"java.lang.String\"")
//         ),
//         "toString",
//         ObjectType(class java.lang.String),
//         List(),
// ...

// %%
val driverWindow = Window.partitionBy("driverId")

val avg_lap_times = spark.read.parquet("../../data/parquet/lap_times.parquet")
    .withColumnRenamed("time", "lapTime")
    .join(races, Seq("raceId"), "right")
    .withColumn("milliseconds", col("milliseconds").cast(IntegerType))
    .withColumn("avgMs", avg(col("milliseconds")).over(driverWindow))
    .dropDuplicates("driverId")
    .select("driverId", "avgMs")
// Out:
// driverWindow: expressions.WindowSpec = org.apache.spark.sql.expressions.WindowSpec@72992eac
// avg_lap_times: DataFrame = [driverId: string, avgMs: double]

// %%
val drivers = spark.read.parquet("../../data/parquet/drivers.parquet")
// Out:
// drivers: DataFrame = [driverId: string, driverRef: string ... 7 more fields]

// %%
val seasonWindow = Window.partitionBy("year")

val lapCount = spark.read.parquet("../../data/parquet/lap_times.parquet")
    .join(races, Seq("raceId"), "right")
    .withColumn("lapsPerDriver", count(col("lap")).over(driverWindow))

val (distinctDrivers, allLaps) = lapCount
    .agg(
        countDistinct("driverID"),
        count(col("lap"))
    ).as[(BigInt, BigInt)]
    .collect()(0)

val avgLapsThisPeriod = allLaps.toInt / distinctDrivers.toInt


//filtrar con isInCollection vv es igual a hacer un join left-anti
val experiencedDrivers = lapCount
    .where(col("lapsPerDriver") >= avgLapsThisPeriod)
    .select("driverId")
    .distinct()
    .as[String]
    .collect()
// Out:
// seasonWindow: expressions.WindowSpec = org.apache.spark.sql.expressions.WindowSpec@38802e0f
// lapCount: DataFrame = [raceId: string, driverId: string ... 12 more fields]
// distinctDrivers: BigInt = 25
// allLaps: BigInt = 25343
// avgLapsThisPeriod: Int = 1013
// experiencedDrivers: Array[String] = Array(
//   "1",
//   "10",
//   "13",
//   "155",
//   "17",
//   "18",
//   "20",
//   "3",
//   "4",
//   "5",
//   "8",
//   "807",
//   "808",
//   "811",
//   "814",
//   "817",
//   "818",
//   "819"
// )

// %%
val mostConsistentDriver = spark.read.parquet("../../data/parquet/results.parquet")
    .join(races, Seq("raceId"), "right")
    .na.drop(Seq("fastestLapTime"))
//     .withColumn("fastestLapTime", regexp_replace(col("fastestLapTime"), "[0-9]|[0-9][0-9]:[0-9][0-9]\\.[0-9][0-9][0-9]", "."))
//     .distinct().show()
    .withColumn("fastestLapTimeMs", lapTimeToMsUDF(col("fastestLapTime")))
    .withColumn("avgFastestLapMs", avg(col("fastestLapTimeMs")).over(driverWindow))
    .dropDuplicates("driverId")
    .join(avg_lap_times, Seq("driverId"), "left")
    .withColumn("diffLapTimes", abs('avgMs - 'avgFastestLapMs).cast(IntegerType))
    .withColumn("avgDiff", msToLapTimeUDF(col("diffLapTimes").cast(IntegerType)))
    .where(col("driverId").isInCollection(experiencedDrivers))
    .join(drivers, "driverId")
    .withColumn("driver", concat(col("forename"), lit(" "), col("surname")))
    .select("driver", "avgDiff")
    .orderBy("avgDiff")
// Out:
// mostConsistentDriver: Dataset[Row] = [driver: string, avgDiff: string]

// %%
// mostConsistentDriver.collect

// %%
def run[A](code: => A): Long = {
    val start = System.currentTimeMillis()
    val res = code
    System.currentTimeMillis() - start
}

def average(list: List[Long]):Long = list.sum / list.size.toLong

def timeTest(f: => Long): Long = {
    val list = (1 to 1).map(_ => f).toList
    average(list)
}

val res = timeTest(run(mostConsistentDriver.collect))
// Out:
// defined function run
// defined function average
// defined function timeTest
// res: Long = 833L
